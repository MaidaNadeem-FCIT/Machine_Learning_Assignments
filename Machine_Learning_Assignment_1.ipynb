# %% [markdown]
# ## Machine Learning                              Assignment # 1
# ### MSDSF22M001                                               Maida Nadeem Butt
# ---
# #### Data Description:
# Due to the growing need of educated and talented individuals, especially in developing countries, recruiting fresh graduates is a routine practice for organizations. Conventional recruiting methods and selection processes can be prone to errors and in order to optimize the whole process, some innovative methods are needed.
#
# #### Column name	Description:
# - Sr#: Serial Number (Ordered Number sequence). (Int)
# - gender: The Gender of the candidate. (String)
# - ssc_percentag: Senior secondary exams percentage (10th Grade). (Float)
# - ssc_board:	Board of education for ssc exams. (String)
# - hsc_percentage:	Higher secondary exams percentage (12th Grade). (Float)
# - hsc_borad:	Board of education for hsc exams. (String)
# - hsc_subject:	Subject of study for hsc .(String)
# - degree_percentage:	Percentage of marks in undergrad degree. (Float)
# - undergrad_degree:	Undergrad degree majors (String)
# - work_experience:	Past work experience. (Boolean)
# - emp_test_percentage:	Aptitude test percentage. (Float)
# - specialization:	Postgrad degree majors - (MBA specialization). (String)
# - mba_percent:	Percentage of marks in MBA degree. (Float)
# - status (TARGET):	Status of placement. Placed / Not Placed. (String)
# ---

# %% [markdown]
# ### Initial plan for data exploration
# ### Step:1  Loading data
# Reading data from **"Job_Placement_Data.csv"** file in my datasets.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("datasets/Job_Placement_Data.csv")

# %% [markdown]
# ### Step:2  Displaying data

# %%
df
# Out:
#      Sr# gender  ssc_percentage ssc_board  hsc_percentage hsc_board  \
# 0      1      M           67.00    Others           91.00    Others
# 1      2      M           79.33   Central           78.33    Others
# 2      3      M           65.00   Central           68.00   Central
# 3      4      M           56.00   Central           52.00   Central
# 4      5      M           85.80   Central           73.60   Central
# ..   ...    ...             ...       ...             ...       ...
# 210  211      M           80.60    Others           82.00    Others
# 211  212      M           58.00    Others           60.00    Others
# 212  213      M           67.00    Others           67.00    Others
# 213  214      F           74.00    Others           66.00    Others
# 214  215      M           62.00   Central           58.00    Others
#
#     hsc_subject  degree_percentage undergrad_degree work_experience  \
# 0      Commerce              58.00         Sci&Tech              No
# ...

# %% [markdown]
# ### Step:3  Review The dataset Structure and Data Types.

# %%
print("DataSet Structure:")
df.info()
# Out:
# DataSet Structure:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sr#                  215 non-null    int64
#  1   gender               215 non-null    object
#  2   ssc_percentage       215 non-null    float64
#  3   ssc_board            214 non-null    object
#  4   hsc_percentage       215 non-null    float64
#  5   hsc_board            215 non-null    object
#  6   hsc_subject          214 non-null    object
#  7   degree_percentage    215 non-null    float64
#  8   undergrad_degree     215 non-null    object
#  9   work_experience      215 non-null    object
#  10  emp_test_percentage  215 non-null    float64
#  11  specialisation       214 non-null    object
#  12  mba_percent          215 non-null    float64
#  13  status               215 non-null    object
# dtypes: float64(5), int64(1), object(8)
# ...

# %%
print("Data Types of Dataset\n",df.dtypes)
# Out:
# Data Types of Dataset
#  Sr#                      int64
# gender                  object
# ssc_percentage         float64
# ssc_board               object
# hsc_percentage         float64
# hsc_board               object
# hsc_subject             object
# degree_percentage      float64
# undergrad_degree        object
# work_experience         object
# emp_test_percentage    float64
# specialisation          object
# mba_percent            float64
# status                  object
# dtype: object

# %% [markdown]
# ### Step:4  Finding the Features of Dataset.

# %%
print("Features of the Dataset include: \n")
print(list(df.columns))
# Out:
# Features of the Dataset include:
#
# ['Sr#', 'gender', 'ssc_percentage', 'ssc_board', 'hsc_percentage', 'hsc_board', 'hsc_subject', 'degree_percentage', 'undergrad_degree', 'work_experience', 'emp_test_percentage', 'specialisation', 'mba_percent', 'status']

# %% [markdown]
# ### Step:5  Finding the total number of records in data set

# %%
print("Number of Records in Dataset:",df.shape[0])
# Out:
# Number of Records in Dataset: 215

# %% [markdown]
# ### Step:6 Finding distribution of each feature
# - Now talking about our continuous variables, we can see that we have some variables
#   like ssc_percentage , hsc_percentage and degree_percentage that the data is practically in a normal distribution,
#   with most of the data in the middle and distributed practically equally left and right.
# - And others that the data is more distributed like emp_test_percentage and mba_percent.

# %%
plt.figure(figsize = (30,20))
sns.set(color_codes = True)

plt.subplot(3,2,1)
sns.histplot(df['ssc_percentage'])

plt.subplot(3,2,2)
sns.histplot(df['hsc_percentage'])

plt.subplot(3,2,3)
sns.histplot(df['degree_percentage'])

plt.subplot(3,2,4)
sns.histplot(df['emp_test_percentage'])

plt.subplot(3,2,5)
sns.histplot(df['mba_percent'])
# Out:
# <AxesSubplot:xlabel='mba_percent', ylabel='Count'>

# %% [markdown]
# ### Step:7 Checking the unique values different features

# %%
dict1= {
    "Feature":df.nunique().index,
    "Unique Values":df.nunique().values
}
pd.DataFrame(dict1)
# Out:
#                 Feature  Unique Values
# 0                   Sr#            215
# 1                gender              2
# 2        ssc_percentage            103
# 3             ssc_board              2
# 4        hsc_percentage             97
# 5             hsc_board              2
# 6           hsc_subject              3
# 7     degree_percentage             89
# 8      undergrad_degree              3
# 9       work_experience              2
# 10  emp_test_percentage            100
# 11       specialisation              2
# 12          mba_percent            205
# 13               status              2

# %% [markdown]
# ### Step:8 Finding distribution of categorical features
# Looking at our categorical variables we managed to get some insights into our database.
# - Most of our data is from male workers
# - Generally our data is from the central.
# - We have little data related to Arts and more data related to Commerce and Science.
# - We can see that most of the data is from Comm&Mngmnt.
# - Most of the data is from people with no experience.
# - When we look at our Target variable we can see that we have more data in Placed than Not Placed.

# %%
plt.figure(figsize = (8,14))

plt.subplot(4,3,1)
sns.countplot(x = 'gender', palette='Set2', data = df)

plt.subplot(4,3,2)
sns.countplot(x = 'ssc_board', palette='Set2', data = df)

plt.subplot(4,3,3)
sns.countplot(x = 'hsc_board', palette='Set2', data = df)

plt.subplot(4,3,4)
sns.countplot(x = 'hsc_subject', palette='Set2', data = df)
plt.xticks(rotation=45)

plt.subplot(4,3,5)
sns.countplot(x = 'undergrad_degree', palette='Set2', data = df)
plt.xticks(rotation=45)

plt.subplot(4,3,6)
sns.countplot(x = 'work_experience', palette='Set2', data = df)

plt.subplot(4,3,7)
sns.countplot(x = 'specialisation', palette='Set2', data = df)
plt.xticks(rotation=45)

plt.subplot(4,3,8)
sns.countplot(x = 'status', palette='Set2', data = df)
plt.xticks(rotation=45)

plt.tight_layout()

# %% [markdown]
# ### Step:9 Finding descriptive statistics to understand the central tendency and spread of the data

# %%
df.describe()
# Out:
#               Sr#  ssc_percentage  hsc_percentage  degree_percentage  \
# count  215.000000      215.000000      215.000000         215.000000
# mean   108.000000       67.303395       66.333163          66.370186
# std     62.209324       10.827205       10.897509           7.358743
# min      1.000000       40.890000       37.000000          50.000000
# 25%     54.500000       60.600000       60.900000          61.000000
# 50%    108.000000       67.000000       65.000000          66.000000
# 75%    161.500000       75.700000       73.000000          72.000000
# max    215.000000       89.400000       97.700000          91.000000
#
#        emp_test_percentage  mba_percent
# count           215.000000   215.000000
# mean             72.100558    62.278186
# std              13.275956     5.833385
# min              50.000000    51.210000
# 25%              60.000000    57.945000
# 50%              71.000000    62.000000
# 75%              83.500000    66.255000
# ...

# %% [markdown]
# ### Step:10 Finding missing values.

# %%
print("Number of Missing Values in each Attribute: ")
df.isna().sum()
# Out:
# Number of Missing Values in each Attribute:
# Sr#                    0
# gender                 0
# ssc_percentage         0
# ssc_board              1
# hsc_percentage         0
# hsc_board              0
# hsc_subject            1
# degree_percentage      0
# undergrad_degree       0
# work_experience        0
# emp_test_percentage    0
# specialisation         1
# mba_percent            0
# status                 0
# dtype: int64

# %% [markdown]
# ## Actions taken for data cleaning and feature engineering.
# ### Step:1  Finding any outliers or anomalies in the data
# Looking at our boxplots we can see that we have no outliers that can influence the model.

# %%
#PLOT OF boxplot()....
fig,ax = plt.subplots()
sp=list(df['ssc_percentage'])
hp=list(df['hsc_percentage'])
dp=list(df['degree_percentage'])
ep=list(df['emp_test_percentage'])
mp=list(df['mba_percent'])
values=[sp,hp,dp,ep,mp]

ax.boxplot(x=values, patch_artist=True, labels=["SSC", "HSC", "Degree", "Aptitude", "MBA"])
ax.set_ylabel("Distribution")
ax.set_xlabel("Continous Variables In Dataset")
plt.title("Anomalies Or Outliers")
plt.xticks(rotation=45)
plt.tight_layout()

# %%
plt.subplot(3,2,1)
sns.boxplot(x = df['ssc_percentage'])

plt.subplot(3,2,2)
sns.boxplot(x = df['hsc_percentage'])

plt.subplot(3,2,3)
sns.boxplot(x = df['degree_percentage'])

plt.subplot(3,2,4)
sns.boxplot(x = df['emp_test_percentage'])
plt.xticks(rotation=45)

plt.subplot(3,2,5)
sns.boxplot(x = df['mba_percent'])
plt.xticks(rotation=45)

plt.tight_layout()

# %% [markdown]
# ### Step:2 Handle missing values by imputing or removing the observations, if necessary..
# Dropping all records having any missing (NaN) Values

# %%
print("Rows * Columns before Dropping NaN values: ",df.shape)
df.dropna(inplace=True)  #all rows with missing values are dropped
print("Rows * Columns After Dropping NaN values: ", df.shape)
# Out:
# Rows * Columns before Dropping NaN values:  (215, 14)
# Rows * Columns After Dropping NaN values:  (212, 14)

# %% [markdown]
# ### Step:3 Convert categorical variables into numerical variables using one-hot encoding or label encoding.
# Converting **"SSC_BOARD"**, **"HSC_BOARD""** and **"Gender"**In Label Encodes...

# %%
df['ssc_board'].replace({"Central":'C', "Others":'O'}, inplace=True)
df['hsc_board'].replace({"Central":'C', "Others":'O'}, inplace=True)
df['gender'].replace({"M":1, "F":0}, inplace=True)
df
# Out:
#      Sr#  gender  ssc_percentage ssc_board  hsc_percentage hsc_board  \
# 0      1       1           67.00         O           91.00         O
# 1      2       1           79.33         C           78.33         O
# 2      3       1           65.00         C           68.00         C
# 3      4       1           56.00         C           52.00         C
# 4      5       1           85.80         C           73.60         C
# ..   ...     ...             ...       ...             ...       ...
# 210  211       1           80.60         O           82.00         O
# 211  212       1           58.00         O           60.00         O
# 212  213       1           67.00         O           67.00         O
# 213  214       0           74.00         O           66.00         O
# 214  215       1           62.00         C           58.00         O
#
#     hsc_subject  degree_percentage undergrad_degree work_experience  \
# 0      Commerce              58.00         Sci&Tech              No
# ...

# %% [markdown]
# ### Step:4 Normalize the features to ensure that the features are on the same scale.
# ---
# - All the dataset is normalized and on the same scale of Float values in any Continous Variable Feature.
# - Continous data variables are percentages in this dataset and they all are in float type.

# %% [markdown]
# ### Step:5 Create new features by combining existing features, if necessary.
# No Combination of Feature is suitable for the current dataset...

# %% [markdown]
# ### Step:6 Remove any irrelevant or redundant features.
# Droping "Sr#" as it is not Necessary for my dataset...

# %%
df.drop(columns=['Sr#'], axis=1, inplace=True)
df
# Out:
#      gender  ssc_percentage ssc_board  hsc_percentage hsc_board hsc_subject  \
# 0         1           67.00         O           91.00         O    Commerce
# 1         1           79.33         C           78.33         O     Science
# 2         1           65.00         C           68.00         C        Arts
# 3         1           56.00         C           52.00         C     Science
# 4         1           85.80         C           73.60         C    Commerce
# ..      ...             ...       ...             ...       ...         ...
# 210       1           80.60         O           82.00         O    Commerce
# 211       1           58.00         O           60.00         O     Science
# 212       1           67.00         O           67.00         O    Commerce
# 213       0           74.00         O           66.00         O    Commerce
# 214       1           62.00         C           58.00         O     Science
#
# ...

# %% [markdown]
# ### Step:7 Visualization of data to find the relationship with different features
# ---
# Verifying the correlation between our variables.
# We can see that we don't have strong correlation between the variables.

# %%
correlation = df.corr()
plt.figure(figsize = (10,5))
sns.heatmap(correlation, annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### BIVARIATE ANALYSIS...
# Looking at our target variable, we can see that:
# - We have a tendency for women not to be reallocated.
# - Another variable that we also see a different behavior is in the work_experience variable,
#   generally those with experience are reallocated more easily.

# %%
plt.figure(figsize = (20, 25))
plt.suptitle("Analysis Of Categoricl Variable Status",fontweight="bold", fontsize=20)

plt.subplot(4,2,1)
sns.countplot(x = 'status', hue = 'gender', palette = 'Set2', data = df)

plt.subplot(4,2,2)
sns.countplot(x = 'status', hue = 'ssc_board', palette = 'Set2', data = df)

plt.subplot(4,2,3)
sns.countplot(x = 'status', hue = 'hsc_board', palette = 'Set2', data = df)

plt.subplot(4,2,4)
sns.countplot(x = 'status', hue = 'hsc_subject', palette = 'Set2', data = df)

plt.subplot(4,2,5)
sns.countplot(x = 'status', hue = 'undergrad_degree', palette = 'Set2', data = df)

plt.subplot(4,2,6)
sns.countplot(x = 'status', hue = 'work_experience', palette = 'Set2', data = df)

plt.subplot(4,2,7)
sns.countplot(x = 'status', hue = 'specialisation', palette = 'Set2', data = df)
# Out:
# <AxesSubplot:xlabel='status', ylabel='count'>

# %% [markdown]
# ### Formulating at least 3 hypotheses about this data
# 1. Now let's analyze the “ssc_percentage” variable to see which profile of employees have the highest score, generally they are employees who are not from the central and more connected to technology and science, we can see that employees linked to art are the ones with the lowest score.
# 2. 	Now comparing with our continuous variables, we can see that generally when the employee has a high “ssc_percentage” score and a high score in the other values, he almost always gets the Placed target.
# 3. We can see that we have a lot of difference between some variables, in the variables ssc_percentage, hsc_percentage and degree_percentage we can see that those with higher grades are allocated more easily than those with lower grades.

# %% [markdown]
# ### Conducting a formal significance test for one of the hypotheses and discuss the results
# Proof Of:
# -  In the variables ssc_percentage, hsc_percentage and degree_percentage we can see that those with higher grades are allocated more easily than those with lower grades.

# %%
plt.figure(figsize = (25, 20))
plt.suptitle("Analysis Of Continous Variable Status",fontweight="bold", fontsize=20)

plt.subplot(3,2,1)
sns.boxplot(x="status", y="ssc_percentage", data=df)

plt.subplot(3,2,2)
sns.boxplot(x="status", y="hsc_percentage", data=df)

plt.subplot(3,2,3)
sns.boxplot(x="status", y="degree_percentage", data=df)

plt.subplot(3,2,4)
sns.boxplot(x="status", y="emp_test_percentage", data=df)

plt.subplot(3,2,5)
sns.boxplot(x="status", y="mba_percent", data=df)
# Out:
# <AxesSubplot:xlabel='status', ylabel='mba_percent'>

# %% [markdown]
# ### Suggestion for next Steps:
# - When importing our base we have little data which makes our work difficult, we do not have a large sample. So, We need to
#   expand our dataset for much deeper analysis.
# - we do not have alot null values.

# %% [markdown]
# ## Summary:
# - Looking at the correlation we can see that there is no strong correlation between our data, when looking at our Exploratory Analysis we can see that we have no outliers, when we look at our categorical variables we can have some conclusions about our database, most of our data are from men, usually from Central, and more focused on Commerce and Science, most of our data has no experience and when we look at our target variable, most of the data is from Placed, When we look at our continuous variables, most tend towards the mean and others are well distributed across all values.
# - When we compare our categorical variables with our Target variable, we can see that the Not Placed result is usually for women, and that generally those with previous experience manage to be relocated, looking at our continuous variables, we can see that those employees who have a higher grade are more likely to be placed.
# - When we take the ssc_percentage variable to analyze, we can see that employees who are not from the central and who are linked to science are more likely to have a higher grade, when compared to our continuous variables, practically in most cases, those who have a high grade are always Placed, but when compared to our Work_experience variable, this employee does not necessarily need to have had previous experience, just having good grades increases your chance a lot.
